# %%
import pandas as pd

# %%
group_people = {
    "first_name": ["Nusrat", "Mehedi", "Tahmid", "Farhana", "Sadia"],
    "last_name":  ["Jahan", "Hasan", "Rahman", "Akter", "Chowdhury"],
    "email": [
        "nusrat.jahan@brac.org",          # illustrative
        "mehedi.hasan@bkash.com",         # illustrative
        "tahmid.rahman@grameenphone.com", # illustrative
        "farhana.akter@robi.com.bd",      # illustrative
        "sadia.chowdhury@du.ac.bd",       # illustrative
    ],
    "company": ["BRAC", "bKash", "Grameenphone", "Robi", "University of Dhaka"],
}

# %%
df = pd.DataFrame(group_people)
df
# Out:
#   first_name  last_name                           email              company
# 0     Nusrat      Jahan           nusrat.jahan@brac.org                 BRAC
# 1     Mehedi      Hasan          mehedi.hasan@bkash.com                bKash
# 2     Tahmid     Rahman  tahmid.rahman@grameenphone.com         Grameenphone
# 3    Farhana      Akter       farhana.akter@robi.com.bd                 Robi
# 4      Sadia  Chowdhury        sadia.chowdhury@du.ac.bd  University of Dhaka

# %%
df.head(3)
# Out:
#   first_name last_name                           email       company
# 0     Nusrat     Jahan           nusrat.jahan@brac.org          BRAC
# 1     Mehedi     Hasan          mehedi.hasan@bkash.com         bKash
# 2     Tahmid    Rahman  tahmid.rahman@grameenphone.com  Grameenphone

# %%
df["company"] == "bKash"
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: company, dtype: bool

# %%
df.loc[df["company"] == "BRAC"]
# Out:
#   first_name last_name                  email company
# 0     Nusrat     Jahan  nusrat.jahan@brac.org    BRAC

# %%
dt = pd.read_csv("..//panda_statistic//datasets//heart_disease_uci.csv")
dt
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 0      lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# 2      lv hypertrophy   129.0   True      2.6         flat  2.0
# 3              normal   187.0  False      3.5  downsloping  0.0
# 4      lv hypertrophy   172.0  False      1.4    upsloping  0.0
# ..                ...     ...    ...      ...          ...  ...
# 915  st-t abnormality   154.0  False      0.0          NaN  NaN
# 916  st-t abnormality     NaN    NaN      NaN          NaN  NaN
# 917  st-t abnormality   100.0  False      0.0          NaN  NaN
# 918    lv hypertrophy     NaN    NaN      NaN          NaN  NaN
# 919    lv hypertrophy    93.0   True      0.0          NaN  NaN
#
#                   thal  num
# 0         fixed defect    0
# 1               normal    2
# 2    reversable defect    1
# 3               normal    0
# 4               normal    0
# ..                 ...  ...
# 915                NaN    1
# 916                NaN    0
# 917       fixed defect    2
# 918                NaN    0
# 919                NaN    1
#
# [920 rows x 16 columns]

# %%
dt.head(5)
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
dt["dataset"].value_counts()
# Out:
# dataset
# Cleveland        304
# Hungary          293
# VA Long Beach    200
# Switzerland      123
# Name: count, dtype: int64

# %%
fitr = dt["dataset"] == "Hungary"

# %%
fitr
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 915    False
# 916    False
# 917    False
# 918    False
# 919    False
# Name: dataset, Length: 920, dtype: bool

# %%
dt.loc[fitr]
# Out:
#       id  age     sex  dataset               cp  trestbps   chol    fbs  \
# 304  305   29    Male  Hungary  atypical angina     120.0  243.0  False
# 305  306   29    Male  Hungary  atypical angina     140.0    NaN  False
# 306  307   30  Female  Hungary   typical angina     170.0  237.0  False
# 307  308   31  Female  Hungary  atypical angina     100.0  219.0  False
# 308  309   32  Female  Hungary  atypical angina     105.0  198.0  False
# ..   ...  ...     ...      ...              ...       ...    ...    ...
# 592  593   52    Male  Hungary     asymptomatic     160.0  331.0  False
# 593  594   54  Female  Hungary      non-anginal     130.0  294.0  False
# 594  595   56    Male  Hungary     asymptomatic     155.0  342.0   True
# 595  596   58  Female  Hungary  atypical angina     180.0  393.0  False
# 596  597   65    Male  Hungary     asymptomatic     130.0  275.0  False
#
#               restecg  thalch  exang  oldpeak slope  ca               thal  \
# 304            normal   160.0  False      0.0   NaN NaN                NaN
# 305            normal   170.0  False      0.0   NaN NaN                NaN
# 306  st-t abnormality   170.0  False      0.0   NaN NaN       fixed defect
# 307  st-t abnormality   150.0  False      0.0   NaN NaN                NaN
# 308            normal   165.0  False      0.0   NaN NaN                NaN
# ..                ...     ...    ...      ...   ...  ..                ...
# 592            normal    94.0   True      2.5   NaN NaN                NaN
# 593  st-t abnormality   100.0   True      0.0  flat NaN                NaN
# 594            normal   150.0   True      3.0  flat NaN                NaN
# 595            normal   110.0   True      1.0  flat NaN  reversable defect
# 596  st-t abnormality   115.0   True      1.0  flat NaN                NaN
#
#      num
# 304    0
# 305    0
# 306    0
# 307    0
# 308    0
# ..   ...
# 592    1
# 593    1
# 594    1
# 595    1
# 596    1
#
# [293 rows x 16 columns]

# %%
fltr = (dt["dataset"] == "Hungary") | ( dt["dataset"] == "Cleveland")

# %%
dt.loc[fltr]
# Out:
#       id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...        ...              ...       ...    ...    ...
# 592  593   52    Male    Hungary     asymptomatic     160.0  331.0  False
# 593  594   54  Female    Hungary      non-anginal     130.0  294.0  False
# 594  595   56    Male    Hungary     asymptomatic     155.0  342.0   True
# 595  596   58  Female    Hungary  atypical angina     180.0  393.0  False
# 596  597   65    Male    Hungary     asymptomatic     130.0  275.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 0      lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# 2      lv hypertrophy   129.0   True      2.6         flat  2.0
# 3              normal   187.0  False      3.5  downsloping  0.0
# 4      lv hypertrophy   172.0  False      1.4    upsloping  0.0
# ..                ...     ...    ...      ...          ...  ...
# 592            normal    94.0   True      2.5          NaN  NaN
# 593  st-t abnormality   100.0   True      0.0         flat  NaN
# 594            normal   150.0   True      3.0         flat  NaN
# 595            normal   110.0   True      1.0         flat  NaN
# 596  st-t abnormality   115.0   True      1.0         flat  NaN
#
#                   thal  num
# 0         fixed defect    0
# 1               normal    2
# 2    reversable defect    1
# 3               normal    0
# 4               normal    0
# ..                 ...  ...
# 592                NaN    1
# 593                NaN    1
# 594                NaN    1
# 595  reversable defect    1
# 596                NaN    1
#
# [597 rows x 16 columns]

# %%
fltr = (dt["age"] < 15 ) & ( dt["sex"] == "Female")

# %%
dt.loc[fltr]
# Out:
# Empty DataFrame
# Columns: [id, age, sex, dataset, cp, trestbps, chol, fbs, restecg, thalch, exang, oldpeak, slope, ca, thal, num]
# Index: []

# %%
dt['age'].min()
# Out:
# np.int64(28)

# %%
dt['age'].max()
# Out:
# np.int64(77)

# %%
dt['age'].mean()
# Out:
# np.float64(53.51086956521739)

# %%
dt['age'].median()
# Out:
# np.float64(54.0)

# %%
dt['age'].mode()
# Out:
# 0    54
# Name: age, dtype: int64

# %%
dt.loc[~((dt["dataset"] == "Hungary") | ( dt["dataset"] == "Cleveland"))]
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 597  598   32    Male    Switzerland   typical angina      95.0    0.0    NaN
# 598  599   34    Male    Switzerland     asymptomatic     115.0    0.0    NaN
# 599  600   35    Male    Switzerland     asymptomatic       NaN    0.0    NaN
# 600  601   36    Male    Switzerland     asymptomatic     110.0    0.0    NaN
# 601  602   38  Female    Switzerland     asymptomatic     105.0    0.0    NaN
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak      slope  ca  \
# 597            normal   127.0  False      0.7  upsloping NaN
# 598               NaN   154.0  False      0.2  upsloping NaN
# 599            normal   130.0   True      NaN        NaN NaN
# 600            normal   125.0   True      1.0       flat NaN
# 601            normal   166.0  False      2.8  upsloping NaN
# ..                ...     ...    ...      ...        ...  ..
# 915  st-t abnormality   154.0  False      0.0        NaN NaN
# 916  st-t abnormality     NaN    NaN      NaN        NaN NaN
# 917  st-t abnormality   100.0  False      0.0        NaN NaN
# 918    lv hypertrophy     NaN    NaN      NaN        NaN NaN
# 919    lv hypertrophy    93.0   True      0.0        NaN NaN
#
#                   thal  num
# 597                NaN    1
# 598                NaN    1
# 599  reversable defect    3
# 600       fixed defect    1
# 601                NaN    2
# ..                 ...  ...
# 915                NaN    1
# 916                NaN    0
# 917       fixed defect    2
# 918                NaN    0
# 919                NaN    1
#
# [323 rows x 16 columns]

# %%
dt["age"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 915    54
# 916    62
# 917    55
# 918    58
# 919    62
# Name: age, Length: 920, dtype: int64>
